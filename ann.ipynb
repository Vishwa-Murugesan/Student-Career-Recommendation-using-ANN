# %%
import os

# List files in current Colab directory
os.listdir("/content")
# Out:
# ['.config', 'Student_performance_data _.csv', 'sample_data']

# %%
import pandas as pd

# Use the exact file name
df = pd.read_csv("/content/Student_performance_data _.csv")

# Check first 5 rows
df.head()
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# 1             0  3.042915         1.0
# 2             0  0.112602         4.0
# 3             0  2.054218         3.0
# 4             0  1.288061         4.0

# %%
df = df.drop("StudentID", axis=1)

# %%
X = df.drop("GradeClass", axis=1)  # Features
y = df["GradeClass"]               # Target

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.utils import to_categorical

# %%
y_train_cat = to_categorical(y_train, num_classes=5)
y_test_cat = to_categorical(y_test, num_classes=5)

# %%
#building the ann
model = Sequential()

# Input layer + first hidden layer
model.add(Dense(32, activation='relu', input_shape=(X_train.shape[1],)))
model.add(Dropout(0.2))

# Second hidden layer
model.add(Dense(16, activation='relu'))
model.add(Dropout(0.2))

# Output layer (5 classes)
model.add(Dense(5, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
#training the model
history = model.fit(
    X_train, y_train_cat,
    validation_split=0.2,
    epochs=50,
    batch_size=32,
    verbose=1
)
# Out:
# Epoch 1/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.3255 - loss: 1.5272 - val_accuracy: 0.4543 - val_loss: 1.4033
# Epoch 2/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5026 - loss: 1.3120 - val_accuracy: 0.4726 - val_loss: 1.2456
# Epoch 3/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5301 - loss: 1.1708 - val_accuracy: 0.4935 - val_loss: 1.1517
# Epoch 4/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5588 - loss: 1.0846 - val_accuracy: 0.5300 - val_loss: 1.0991
# Epoch 5/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5830 - loss: 1.0455 - val_accuracy: 0.5614 - val_loss: 1.0571
# Epoch 6/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6288 - loss: 0.9835 - val_accuracy: 0.6005 - val_loss: 1.0339
# Epoch 7/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6275 - loss: 0.9644 - val_accuracy: 0.6110 - val_loss: 1.0141
# Epoch 8/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6431 - loss: 0.9350 - val_accuracy: 0.6397 - val_loss: 0.9928
# Epoch 9/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6699 - loss: 0.9206 - val_accuracy: 0.6527 - val_loss: 0.9751
# Epoch 10/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6778 - loss: 0.9170 - val_accuracy: 0.6606 - val_loss: 0.9613
# Epoch 11/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7059 - loss: 0.8625 - val_accuracy: 0.6893 - val_loss: 0.9386
# Epoch 12/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7105 - loss: 0.8896 - val_accuracy: 0.6762 - val_loss: 0.9258
# Epoch 13/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7098 - loss: 0.8500 - val_accuracy: 0.6815 - val_loss: 0.9128
# Epoch 14/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7118 - loss: 0.8345 - val_accuracy: 0.6893 - val_loss: 0.9043
# Epoch 15/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7196 - loss: 0.8283 - val_accuracy: 0.6997 - val_loss: 0.8941
# Epoch 16/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7209 - loss: 0.8213 - val_accuracy: 0.7102 - val_loss: 0.8799
# Epoch 17/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7301 - loss: 0.8172 - val_accuracy: 0.7180 - val_loss: 0.8707
# Epoch 18/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7346 - loss: 0.8016 - val_accuracy: 0.7180 - val_loss: 0.8683
# Epoch 19/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7242 - loss: 0.7992 - val_accuracy: 0.7363 - val_loss: 0.8565
# Epoch 20/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7431 - loss: 0.7804 - val_accuracy: 0.7337 - val_loss: 0.8507
# Epoch 21/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7399 - loss: 0.7901 - val_accuracy: 0.7363 - val_loss: 0.8412
# Epoch 22/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7399 - loss: 0.7797 - val_accuracy: 0.7572 - val_loss: 0.8329
# Epoch 23/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7471 - loss: 0.7576 - val_accuracy: 0.7650 - val_loss: 0.8252
# Epoch 24/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7516 - loss: 0.7636 - val_accuracy: 0.7728 - val_loss: 0.8149
# Epoch 25/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7529 - loss: 0.7438 - val_accuracy: 0.7650 - val_loss: 0.8111
# Epoch 26/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7569 - loss: 0.7454 - val_accuracy: 0.7676 - val_loss: 0.8034
# Epoch 27/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7660 - loss: 0.7318 - val_accuracy: 0.7728 - val_loss: 0.8015
# Epoch 28/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7556 - loss: 0.7294 - val_accuracy: 0.7650 - val_loss: 0.7958
# Epoch 29/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7712 - loss: 0.7216 - val_accuracy: 0.7807 - val_loss: 0.7897
# Epoch 30/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7562 - loss: 0.7246 - val_accuracy: 0.7781 - val_loss: 0.7854
# Epoch 31/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7706 - loss: 0.7257 - val_accuracy: 0.7859 - val_loss: 0.7816
# Epoch 32/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7627 - loss: 0.7189 - val_accuracy: 0.7859 - val_loss: 0.7792
# Epoch 33/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7908 - loss: 0.7112 - val_accuracy: 0.7781 - val_loss: 0.7710
# Epoch 34/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7810 - loss: 0.7001 - val_accuracy: 0.7833 - val_loss: 0.7736
# Epoch 35/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7863 - loss: 0.6909 - val_accuracy: 0.7859 - val_loss: 0.7629
# Epoch 36/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7817 - loss: 0.6928 - val_accuracy: 0.7781 - val_loss: 0.7648
# Epoch 37/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7830 - loss: 0.6822 - val_accuracy: 0.7755 - val_loss: 0.7609
# Epoch 38/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7876 - loss: 0.6822 - val_accuracy: 0.7833 - val_loss: 0.7598
# Epoch 39/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7856 - loss: 0.6814 - val_accuracy: 0.7807 - val_loss: 0.7518
# Epoch 40/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7863 - loss: 0.6709 - val_accuracy: 0.7859 - val_loss: 0.7490
# Epoch 41/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7882 - loss: 0.6649 - val_accuracy: 0.7859 - val_loss: 0.7488
# Epoch 42/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7895 - loss: 0.6781 - val_accuracy: 0.7859 - val_loss: 0.7425
# Epoch 43/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7915 - loss: 0.6528 - val_accuracy: 0.7885 - val_loss: 0.7419
# Epoch 44/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7967 - loss: 0.6612 - val_accuracy: 0.7937 - val_loss: 0.7376
# Epoch 45/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8124 - loss: 0.6384 - val_accuracy: 0.7937 - val_loss: 0.7347
# Epoch 46/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8085 - loss: 0.6427 - val_accuracy: 0.7937 - val_loss: 0.7292
# Epoch 47/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7974 - loss: 0.6613 - val_accuracy: 0.8068 - val_loss: 0.7308
# Epoch 48/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8033 - loss: 0.6489 - val_accuracy: 0.8068 - val_loss: 0.7268
# Epoch 49/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8078 - loss: 0.6283 - val_accuracy: 0.8042 - val_loss: 0.7242
# Epoch 50/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8052 - loss: 0.6343 - val_accuracy: 0.7937 - val_loss: 0.7252

# %%
# Predict probabilities
y_pred_prob = model.predict(X_test)

# Convert probabilities to class labels
y_pred = y_pred_prob.argmax(axis=1)
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-Score: {f1:.4f}")
# Out:
# Accuracy: 0.8017
# Precision: 0.8065
# Recall: 0.8017
# F1-Score: 0.7832

# %%
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[  1  14   3   2   2]
#  [  0  26  18   1   4]
#  [  0   4  65  11   5]
#  [  0   2   5  63  16]
#  [  0   1   0   7 229]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=[0,1,2,3,4], yticklabels=[0,1,2,3,4])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
